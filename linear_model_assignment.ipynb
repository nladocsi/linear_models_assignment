# %% [markdown]
# <a href="https://colab.research.google.com/github/nladocsi/linear_models_assignment/blob/main/linear_model_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment: Linear Models
# ## Do two questions in total: "Q1+Q2" or "Q1+Q3"
# ### `! git clone https://github.com/ds3001f25/linear_models_assignment.git`

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# **Q1.** Let's explore multiple linear regression in a two-variable case, to build more intuition about what is happening.
#
# Suppose the model is
# $$
# \hat{y}_i = b_0 + b_1 z_{i1} + b_2 z_{i2}
# $$
# Assume that $z_{ij}$ is centered or de-meaned, so that $z_{ij} = x_{ij} - m_j$ where $m_j$ is the mean of variable $j$ and $x_{ij}$ is the original value of variable $j$ for observation $i$. Notice that this implies
# $$
# \dfrac{1}{N} \sum_{i=1}^N z_{ij} = 0
# $$
# which will simplify your calculations below substantially!
#
# 1. Write down the SSE for this model.
# 2. Take partial derivatives with respect to $b_0$, $b_1$, and $b_2$.
# 3. Verify that the average error is zero and $e \cdot z =0$ at the optimum, just as in the single linear regression case.
# 4. Show that the optimal intercept is $b_0^* = \bar{y}$. Eliminate $b_0^*$ from the remaining equations, and focus on $b_1$ and $b_2$.
# 5. Write your results as a matrix equation in the form "$Ab=C$". These are called the **normal equations**.
# 6. Divide both sides by $N$ and substitute $z_{ij} = x_{ij} - m_j$ back into your normal equations for $x_{ij}$. What is the matrix $A$? What is the vector $C$? Explain the intuition of your discovery.

# %% [markdown]
# **Q2.** This question is a case study for linear models. The data are about car prices. In particular, they include:
#
#   - `Price`, `Color`, `Seating_Capacity`
#   - `Body_Type`: crossover, hatchback, muv, sedan, suv
#   - `Make`, `Make_Year`: The brand of car and year produced
#   - `Mileage_Run`: The number of miles on the odometer
#   - `Fuel_Type`: Diesel or gasoline/petrol
#   - `Transmission`, `Transmission_Type`:  speeds and automatic/manual
#
#   1. Load `cars_hw.csv`. These data were really dirty, and I've already cleaned them a significant amount in terms of missing values and other issues, but some issues remain (e.g. outliers, badly scaled variables that require a log or arcsinh transformation). Clean the data however you think is most appropriate.
#   2. Summarize the `Price` variable and create a kernel density plot. Use `.groupby()` and `.describe()` to summarize prices by brand (`Make`). Make a grouped kernel density plot by `Make`. Which car brands are the most expensive? What do prices look like in general?
#   3. Split the data into an 80% training set and a 20% testing set.
#   4. Make a model where you regress price on the numeric variables alone; what is the $R^2$ and `RMSE` on the training set and test set? Make a second model where, for the categorical variables, you regress price on a model comprised of one-hot encoded regressors/features alone (you can use `pd.get_dummies()`; be careful of the dummy variable trap); what is the $R^2$ and `RMSE` on the test set? Which model performs better on the test set? Make a third model that combines all the regressors from the previous two; what is the $R^2$ and `RMSE` on the test set? Does the joint model perform better or worse, and by home much?
#   5. Use the `PolynomialFeatures` function from `sklearn` to expand the set of numerical variables you're using in the regression. As you increase the degree of the expansion, how do the $R^2$ and `RMSE` change? At what point does $R^2$ go negative on the test set? For your best model with expanded features, what is the $R^2$ and `RMSE`? How does it compare to your best model from part 4?
#   6. For your best model so far, determine the predicted values for the test data and plot them against the true values. Do the predicted values and true values roughly line up along the diagonal, or not? Compute the residuals/errors for the test data and create a kernel density plot. Do the residuals look roughly bell-shaped around zero? Evaluate the strengths and weaknesses of your model.

# %%
#2.1
df = pd.read_csv('cars_hw.csv')
df = df.drop(columns=['Unnamed: 0'])
df["No_of_Owners"] = df["No_of_Owners"].str.replace("st|nd|rd|th", "", regex=True).astype(int)

#Check if variables need log:
#df['Price'].plot.box()
df = df.loc[df['Price'] < 1_300_000, :]
df['Price'].plot.box()
#df['Mileage_Run'].plot.box() #No outliers

df.head()

#Other checks for outliers
#print(df['Transmission'].value_counts(), '\n')
#(df['Color'].unique(),'\n')
# Out:
#          Make  Make_Year   Color  Body_Type  Mileage_Run  No_of_Owners  \
# 0  Volkswagen       2017  silver      sedan        44611             1
# 1     Hyundai       2016     red  crossover        20305             1
# 2       Honda       2019   white        suv        29540             2
# 3     Renault       2017  bronze  hatchback        35680             1
# 4     Hyundai       2017  orange  hatchback        25126             1
#
#    Seating_Capacity Fuel_Type Transmission Transmission_Type   Price
# 0                 5    diesel      7-Speed         Automatic  657000
# 1                 5    petrol      5-Speed            Manual  682000
# 2                 5    petrol      5-Speed            Manual  793000
# 3                 5    petrol      5-Speed            Manual  414000
# 4                 5    petrol      5-Speed            Manual  515000

# %%
#2.2.1
psum = df["Price"].describe()
print(psum)

sns.kdeplot(df["Price"].dropna(), bw_adjust=0.8, fill=False)
plt.title("Price Distribution")
# Out:
# count    9.070000e+02
# mean     6.648688e+05
# std      2.405520e+05
# min      1.880000e+05
# 25%      4.610000e+05
# 50%      6.430000e+05
# 75%      8.235000e+05
# max      1.299000e+06
# Name: Price, dtype: float64
# Text(0.5, 1.0, 'Price Distribution')

# %%
#2.2.2
mp_sum = df.groupby('Make')['Price'].describe()
print(mp_sum)

counts = df["Make"].value_counts()
df = df[df["Make"].isin(counts[counts > 10].index)]
sns.kdeplot(data=df, x='Price', hue='Make', fill=False, common_norm=False, alpha=0.4, linewidth=1.5)

plt.title("Price Distribution")
# Out:
#                count          mean            std        min        25%  \
# Make
# Chevrolet        6.0  4.535000e+05  246606.366503   267000.0   288500.0
# Datsun           3.0  2.896667e+05   10503.967504   279000.0   284500.0
# Ford            52.0  7.211731e+05  140927.699605   290000.0   635000.0
# Honda           67.0  7.463284e+05  206805.602472   316000.0   579000.0
# Hyundai        298.0  6.733993e+05  254012.032642   248000.0   484000.0
# Jeep             1.0  1.290000e+06            NaN  1290000.0  1290000.0
# Mahindra        16.0  1.058688e+06  135145.708404   796000.0  1003000.0
# Maruti Suzuki  293.0  5.887850e+05  216019.860943   237000.0   411000.0
# Nissan           4.0  8.842500e+05  289559.867155   475000.0   782500.0
# Renault         68.0  6.625735e+05  214827.338943   287000.0   475000.0
# Skoda            4.0  6.847500e+05  411730.797974   436000.0   458500.0
# Tata            16.0  7.255000e+05  234496.623998   188000.0   612000.0
# ...

# %% [markdown]
# *  The most expensive car brands are Skoda, Honda, Hyundai, Jeep and Mahindra with the highest max prices. The highest average prices for car make were jeep and Hyundai.
# *   In general prices have a cluster around $500,000 and $1,000,000. It is rare that the cars would be below $250000 or above $1500000.
# *   The density plot shows mostly unimodal or bimodal

# %%
#2.3
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)


#check
#print("Training set size:", train_df.shape[0])
#print("Testing set size:", test_df.shape[0])
#print("Total rows:", df.shape[0])

# %%
#2.4.1
y_train = train_df['Price'] # Target variable
y_test = test_df['Price'] # Target variable

numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
numeric_cols.remove('Price')

x_train = train_df[numeric_cols]
x_test = test_df[numeric_cols]

model = LinearRegression()
model.fit(x_train, y_train)

y_train_pred = model.predict(x_train)
y_test_pred = model.predict(x_test)

train_r2 = model.score(x_train, y_train)
test_r2 = model.score(x_test, y_test)

train_rmse = np.sqrt(np.mean((y_train - y_train_pred)**2))
test_rmse = np.sqrt(np.mean((y_test - y_test_pred)**2))

print("Training R^2:", train_r2)
print("Testing R^2:", test_r2)
print("Training RMSE:", train_rmse)
print("Testing RMSE:", test_rmse)
# Out:
# Training R^2: 0.32525405210623926
# Testing R^2: 0.39488004669487875
# Training RMSE: 198144.50781442397
# Testing RMSE: 171595.07308835772

# %%
#2.4.2

categor_cols = df.select_dtypes(include=['object', 'category']).columns.tolist()

x_train_cat = pd.get_dummies(train_df[categor_cols], drop_first=True)
x_test_cat = pd.get_dummies(test_df[categor_cols], drop_first=True)

x_test_cat = x_test_cat.reindex(columns=x_train_cat.columns, fill_value=0)

model_cat = LinearRegression()
model_cat.fit(x_train_cat, y_train)

y_test_pred_cat = model_cat.predict(x_test_cat)

test_r2_cat = model_cat.score(x_test_cat, y_test)
test_rmse_cat = np.sqrt(np.mean((y_test - y_test_pred_cat)**2))

print("Categorical Model - Testing R^2:", test_r2_cat)
print("Categorical Model - Testing RMSE:", test_rmse_cat)
# Out:
# Categorical Model - Testing R^2: 0.47744950886006676
# Categorical Model - Testing RMSE: 159458.69566631623

# %%
#2.4.3
x_train_all = pd.concat([x_train, x_train_cat], axis=1)
x_test_all = pd.concat([x_test, x_test_cat], axis=1)

model_all = LinearRegression()
model_all.fit(x_train_all, y_train)

y_test_pred_all = model_all.predict(x_test_all)

test_r2_all = model_all.score(x_test_all, y_test)
test_rmse_all = np.sqrt(np.mean((y_test - y_test_pred_all)**2))

print("All Model - Testing R^2:", test_r2_all)
print("All Model - Testing RMSE:", test_rmse_all)
# Out:
# All Model - Testing R^2: 0.7310138010267648
# All Model - Testing RMSE: 114406.0723546563

# %% [markdown]
# **Model Performance**
#
# The categorical model performes better on the test set. The joint model performes better than all other models. It is a significantly better model with a 25.4% improvement compared with the categorical model and a 33.6% improvement compared to hte numeric model.

# %%
#2.5
for degree in range(1,11):
  expander = PolynomialFeatures(degree=degree, include_bias=False)
  z_train = expander.fit_transform(x_train)
  z_test = expander.transform(x_test)

  names = expander.get_feature_names_out(numeric_cols)  # get feature names
  z_train_df = pd.DataFrame(data=z_train, columns=names, index=train_df.index)
  z_test_df = pd.DataFrame(data=z_test, columns=names, index=test_df.index)

  model = LinearRegression()
  model.fit(z_train_df, y_train)

  y_test_pred = model.predict(z_test_df)
  test_r2 = model.score(z_test_df, y_test)
  test_rmse = np.sqrt(np.mean((y_test - y_test_pred)**2))

  print(f"Degree {degree}:")
  print("Testing R^2:", test_r2)
  print("Testing RMSE:", test_rmse)
  print()

  if test_r2 < 0:
    print("R^2 goes negative at degree", degree)
    break
# Out:
# Degree 1:
# Testing R^2: 0.39488004669487875
# Testing RMSE: 171595.07308835772
#
# Degree 2:
# Testing R^2: 0.4312705823056421
# Testing RMSE: 166355.40794167612
#
# Degree 3:
# Testing R^2: 0.4051706234997474
# Testing RMSE: 170129.75693679607
#
# Degree 4:
# Testing R^2: 0.4020943819133739
# Testing RMSE: 170569.1142893536
#
# Degree 5:
# Testing R^2: 0.40570826214809574
# Testing RMSE: 170052.85336241144
#
# Degree 6:
# Testing R^2: 0.41953248696218637
# Testing RMSE: 168063.35792104836
#
# Degree 7:
# Testing R^2: 0.348464563247209
# Testing RMSE: 178054.55902549985
#
# Degree 8:
# Testing R^2: -0.1986522653630045
# Testing RMSE: 241507.5334681577
#
# R^2 goes negative at degree 8

# %% [markdown]
# **Expansion Analysis**
#
# *   As the degree increases from 1 to 2 the R^2 increase and RMSE decreases (improvement in model)
# *   After degree 2 R^2 has fluctuations and RMSE gets worse. This observation would suggest overfitting.
# *   Once degree 8 is reached R^2 becomes negative. This signifies the model performs worse than mean prediction.
# *   The best performance is at degree 2.
# *   In comparision to part 4 it is still worse than the joint model when comparins the R^2 and RMSE.
# *   Combining feature types matters more than adding higher-degree polynomial terms.

# %%
#2.6.1
y_test_pred = model_all.predict(x_test_all)


sns.scatterplot(x=y_test, y=y_test_pred)
plt.xlabel("True Values")
plt.ylabel("Predicted Values")
plt.title("True vs. Predicted Values")
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red')
plt.show()

# %%
#2.6.2
residuals = y_test - y_test_pred
sns.kdeplot(residuals, bw_adjust=0.8, fill=False)
plt.title("Residuals Distribution")
# Out:
# Text(0.5, 1.0, 'Residuals Distribution')

# %% [markdown]
# **Q6 Responses**
# *   There is a rough diagonal line up with predicted values and true values.
# *   Yes the residuals look roughly bell-shaped around zero.
#
# **Strengths**
#
# *   For the scatter plot the predictions track the true values very closely.
# *   The residuals are centered at zero
# *   The R^2 = 0.73 this shows a strong fit
#
# **Weaknesses**
#
# *   Some outliers are found with large distances from the line
# *   The model does not fully caputure the high end prices (choice made to make the plots more visually appealing)
# *   High variance in predictions , could be overfitting or underfitting in parts of price extremes.

# %% [markdown]
# **Q3.** This question refers to the `heart_hw.csv` data. It contains three variables:
#
#   - `y`: Whether the individual survived for three years, coded 0 for death and 1 for survival
#   - `age`: Patient's age
#   - `transplant`: `control` for not receiving a transplant and `treatment` for receiving a transplant
#
# Since a heart transplant is a dangerous operation and even people who successfully get heart transplants might suffer later complications, we want to look at whether a group of transplant recipients tends to survive longer than a comparison group who does not get the procedure.
#
# 1. Compute (a) the proportion of people who survive in the control group who do not receive a transplant, and (b) the difference between the proportion of people who survive in the treatment group and the proportion of people who survive in the control group. In a randomized controlled trial, this is called the **average treatment effect**.
# 2. Regress `y` on `transplant` using a linear model with a constant. How does the constant/intercept of the regression and the coefficient on transplant compare to your answers from part 1? Explain the relationship clearly.
# 3. We'd like to include `age` in the regression, since it's reasonable to expect that older patients are less likely to survive an extensive surgery like a heart transplant. Regress `y` on a constant, transplant, and age. How does the intercept change?
# 4. Build a more flexible model that allows for non-linear age effects and interactions between age and treatment. Use a train-test split to validate your model. Estimate your best model, predict the survival probability by age, and plot your results conditional on receiving a transplant and not. Describe what you see.
# 5. Imagine someone suggests using these kinds of models to select who receives organ transplants; perhaps the CDC or NIH starts using a scoring algorithm to decide who is contacted about a potential organ. What are your concerns about how it is built and how it is deployed?
